# %%
import pandas as pd

# A megadott JSON tartalmak betöltése szótárakba
data_ieee = {
    "logistic_regression": {
        "accuracy": 0.8210112778135266,
        "f1_score": 0.8752323761652767,
        "precision": 0.9587239621501196,
        "recall": 0.8210112778135266,
        "roc_auc": 0.8608238899326076,
        "pr_auc": 0.4324358576367741,
        "cp_coverage": 0.900844989331798,
        "cp_avg_set_size": 1.204211399735835,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "random_forest": {
        "accuracy": 0.926804280827717,
        "f1_score": 0.9408038773159467,
        "precision": 0.9613561327474841,
        "recall": 0.926804280827717,
        "roc_auc": 0.8853070936439076,
        "pr_auc": 0.494759224090473,
        "cp_coverage": 0.9016154705862431,
        "cp_avg_set_size": 0.9548633454126731,
        "cp_empty_set_ratio": 0.04513665458732685,
        "alpha": 0.1
    },
    "gradient_boosting": {
        "accuracy": 0.9753022657228977,
        "f1_score": 0.9717849756434309,
        "precision": 0.9719672541729766,
        "recall": 0.9753022657228977,
        "roc_auc": 0.9076927051603498,
        "pr_auc": 0.5764971189148563,
        "cp_coverage": 0.898736749415789,
        "cp_avg_set_size": 0.9090324110136485,
        "cp_empty_set_ratio": 0.09096758898635147,
        "alpha": 0.1
    },
    "svc": {
        "error": "Unable to allocate 1.65 GiB for an array with shape (531885, 417) and data type float64"
    },
    "isolation_forest": {
        "accuracy": 0.9288701866088664,
        "f1_score": 0.9377341006885844,
        "precision": 0.9482089839577026,
        "recall": 0.9288701866088664,
        "roc_auc": 0.7701030566945827,
        "pr_auc": 0.13963238830755204
    },
    "ocsgd": {
        "accuracy": 0.9201747553087005,
        "f1_score": 0.9278197747580308,
        "precision": 0.9358807339805543,
        "recall": 0.9201747553087005,
        "roc_auc": 0.562603512184549,
        "pr_auc": 0.05468676081886449
    }
}

data_sparkov = {
    "logistic_regression": {
        "accuracy": 0.8716216476757861,
        "f1_score": 0.926066132268143,
        "precision": 0.9927988043794123,
        "recall": 0.8716216476757861,
        "roc_auc": 0.9089731889686012,
        "pr_auc": 0.19004207481359722,
        "cp_coverage": 0.901579038695124,
        "cp_avg_set_size": 1.060817089864461,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "random_forest": {
        "accuracy": 0.9884705111149671,
        "f1_score": 0.9911286668488194,
        "precision": 0.9953441319072361,
        "recall": 0.9884705111149671,
        "roc_auc": 0.984575286206516,
        "pr_auc": 0.7518208285795744,
        "cp_coverage": 0.9008695316868144,
        "cp_avg_set_size": 0.9038001041124414,
        "cp_empty_set_ratio": 0.09619989588755856,
        "alpha": 0.1
    },
    "gradient_boosting": {
        "accuracy": 0.9951221393178707,
        "f1_score": 0.9956674707326844,
        "precision": 0.996635400245686,
        "recall": 0.9951221393178707,
        "roc_auc": 0.9962176108879209,
        "pr_auc": 0.859323607828443,
        "cp_coverage": 0.90090423583396,
        "cp_avg_set_size": 0.9010777565696878,
        "cp_empty_set_ratio": 0.09892224343031214,
        "alpha": 0.1
    },
    "svc": {
        "accuracy": 0.8220949736826885,
        "f1_score": 0.8969445035462601,
        "precision": 0.9925866223930958,
        "recall": 0.8220949736826885,
        "roc_auc": 0.9045169185982973,
        "pr_auc": 0.23043346491995603,
        "cp_coverage": 0.9008425395723678,
        "cp_avg_set_size": 1.1217575722521063,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "isolation_forest": {
        "accuracy": 0.9457689860605009,
        "f1_score": 0.9667027795971047,
        "precision": 0.9894714710875779,
        "recall": 0.9457689860605009,
        "roc_auc": 0.7413888412686725,
        "pr_auc": 0.02131408241855512
    },
    "ocsgd": {
        "accuracy": 0.9094992962770162,
        "f1_score": 0.9471543403364411,
        "precision": 0.9888670596855864,
        "recall": 0.9094992962770162,
        "roc_auc": 0.5525069151263869,
        "pr_auc": 0.008918521528509872
    }
}

data_bot = {
    "logistic_regression": {
        "accuracy": 0.7152777777777778,
        "f1_score": 0.7235681193613454,
        "precision": 0.7695920335045522,
        "recall": 0.7152777777777778,
        "roc_auc": 0.8116925418189729,
        "pr_auc": 0.635531776454984,
        "cp_coverage": 0.8866185897435898,
        "cp_avg_set_size": 1.4135950854700854,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "random_forest": {
        "accuracy": 0.8311965811965812,
        "f1_score": 0.8337015377011299,
        "precision": 0.8399761072888361,
        "recall": 0.8311965811965812,
        "roc_auc": 0.9132038684234127,
        "pr_auc": 0.8569810902769958,
        "cp_coverage": 0.8874198717948718,
        "cp_avg_set_size": 1.1147168803418803,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "gradient_boosting": {
        "accuracy": 0.8637820512820513,
        "f1_score": 0.8640920955937602,
        "precision": 0.8644721974519982,
        "recall": 0.8637820512820513,
        "roc_auc": 0.928715044615082,
        "pr_auc": 0.8861129525271597,
        "cp_coverage": 0.8932959401709402,
        "cp_avg_set_size": 1.0661057692307692,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "svc": {
        "accuracy": 0.7162126068376068,
        "f1_score": 0.7243725327946449,
        "precision": 0.7617779619045865,
        "recall": 0.7162126068376068,
        "roc_auc": 0.806604809749965,
        "pr_auc": 0.6287912290374289,
        "cp_coverage": 0.8854166666666666,
        "cp_avg_set_size": 1.421207264957265,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "isolation_forest": {
        "accuracy": 0.6473023504273504,
        "f1_score": 0.5493283283187145,
        "precision": 0.5447948237796612,
        "recall": 0.6473023504273504,
        "roc_auc": 0.4463502984728278,
        "pr_auc": 0.3051150079838185
    },
    "ocsgd": {
        "accuracy": 0.6440972222222222,
        "f1_score": 0.5520467988391365,
        "precision": 0.5468271771687002,
        "recall": 0.6440972222222222,
        "roc_auc": 0.4966129376699936,
        "pr_auc": 0.3367536680337578
    }
}

data_vehicle = {
    "logistic_regression": {
        "accuracy": 0.5634878085393836,
        "f1_score": 0.6015287232506529,
        "precision": 0.7219763609360951,
        "recall": 0.5634878085393836,
        "roc_auc": 0.6246218617730435,
        "pr_auc": 0.2995874212572961,
        "cp_coverage": 0.8997876948810877,
        "cp_avg_set_size": 1.6827217945143789,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "random_forest": {
        "accuracy": 0.6141836975402629,
        "f1_score": 0.6461329005384336,
        "precision": 0.7158571947623474,
        "recall": 0.6141836975402629,
        "roc_auc": 0.6301263969855093,
        "pr_auc": 0.3081044128912044,
        "cp_coverage": 0.8997233599965688,
        "cp_avg_set_size": 1.5520361990950227,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "gradient_boosting": {
        "accuracy": 0.7094851064742339,
        "f1_score": 0.7074857621877524,
        "precision": 0.7055689755759282,
        "recall": 0.7094851064742339,
        "roc_auc": 0.630106067882594,
        "pr_auc": 0.3071935350402633,
        "cp_coverage": 0.9015676266861101,
        "cp_avg_set_size": 1.4448328365250585,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "svc": {
        "accuracy": 0.5637022581544466,
        "f1_score": 0.6017406162693059,
        "precision": 0.7217016760351399,
        "recall": 0.5637022581544466,
        "roc_auc": 0.6244313378264263,
        "pr_auc": 0.29946687381056336,
        "cp_coverage": 0.8997448049580751,
        "cp_avg_set_size": 1.6828504642834166,
        "cp_empty_set_ratio": 0.0,
        "alpha": 0.1
    },
    "isolation_forest": {
        "accuracy": 0.7523964744483284,
        "f1_score": 0.6867746211736087,
        "precision": 0.6540542723422972,
        "recall": 0.7523964744483284,
        "roc_auc": 0.4929492731338385,
        "pr_auc": 0.21284412919789733
    },
    "ocsgd": {
        "accuracy": 0.7631189552014754,
        "f1_score": 0.6899054502508754,
        "precision": 0.6600655751861955,
        "recall": 0.7631189552014754,
        "roc_auc": 0.5305382674519132,
        "pr_auc": 0.23234284395887517
    }
}

data_ulb = {
    "logistic_regression": {
        "accuracy": 0.97382465503318,
        "f1_score": 0.9852052370407748,
        "precision": 0.9982338064229239,
        "recall": 0.97382465503318,
        "roc_auc": 0.975483484403891,
        "pr_auc": 0.7308412958821945,
        "cp_coverage": 0.8952986201327201,
        "cp_avg_set_size": 0.9041641796285242,
        "cp_empty_set_ratio": 0.09583582037147573,
        "alpha": 0.1
    },
    "random_forest": {
        "accuracy": 0.998121554720691,
        "f1_score": 0.998395531636902,
        "precision": 0.9988679781006029,
        "recall": 0.998121554720691,
        "roc_auc": 0.9826338244920928,
        "pr_auc": 0.8073739486611334,
        "cp_coverage": 0.8979670657631403,
        "cp_avg_set_size": 0.8982830659035849,
        "cp_empty_set_ratio": 0.10171693409641515,
        "alpha": 0.1
    },
    "gradient_boosting": {
        "accuracy": 0.9988413328183702,
        "f1_score": 0.9989393211196043,
        "precision": 0.9991108663280369,
        "recall": 0.9988413328183702,
        "roc_auc": 0.9845582155203105,
        "pr_auc": 0.8613386314506716,
        "cp_coverage": 0.8960886204838313,
        "cp_avg_set_size": 0.8961763983006215,
        "cp_empty_set_ratio": 0.10382360169937853,
        "alpha": 0.1
    },
    "svc": {
        "accuracy": 0.9729117657385625,
        "f1_score": 0.9847292962651337,
        "precision": 0.9982115442224351,
        "recall": 0.9729117657385625,
        "roc_auc": 0.9775029824113101,
        "pr_auc": 0.7160471137374997,
        "cp_coverage": 0.8957550647800288,
        "cp_avg_set_size": 0.9059372915276851,
        "cp_empty_set_ratio": 0.09406270847231488,
        "alpha": 0.1
    },
    "isolation_forest": {
        "accuracy": 0.948843088374706,
        "f1_score": 0.9721288927132826,
        "precision": 0.9980690668508654,
        "recall": 0.948843088374706,
        "roc_auc": 0.9579745587036165,
        "pr_auc": 0.1664353984169036
    },
    "ocsgd": {
        "accuracy": 0.9624662055405357,
        "f1_score": 0.9791866300226688,
        "precision": 0.9964982759523876,
        "recall": 0.9624662055405357,
        "roc_auc": 0.03174473573897763,
        "pr_auc": 0.000873935995474119
    }
}

datasets = {
    "IEEE Fraud": data_ieee,
    "Sparkov Fraud": data_sparkov,
    "Bot Accounts": data_bot,
    "Vehicle Loan": data_vehicle,
    "ulb":data_ulb
}

# Adatok átalakítása DataFrame-hez megfelelő formátumba
all_data = []
for dataset_name, content in datasets.items():
    for model, metrics in content.items():
        row = {"Dataset": dataset_name, "Model": model}
        
        if "error" in metrics:
            row["Error_Message"] = metrics["error"]
        else:
            row.update(metrics)
            
        all_data.append(row)

df_combined = pd.DataFrame(all_data)

# Oszlopok rendezése (Dataset és Model legyen elöl)
cols = ["Dataset", "Model"] + [c for c in df_combined.columns if c not in ["Dataset", "Model", "Error_Message"]] + ["Error_Message"]
df_combined = df_combined[cols]

# Mentés Excel fájlba
output_file = "benchmark_summaries_combined.xlsx"
df_combined.to_excel(output_file, index=False)

print(output_file)
# Out:
# benchmark_summaries_combined.xlsx
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
